# %% [markdown]
# ### Instructions:
# * Download the Yellow Taxi Data for April from the main source here https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
# * Use pandas to inspect the data and perform some transformations
# * Finally, write the output as Parquet file
#
# > __Note__: File is being provided for you in this location `In class/data/yellow_tripdata_2024-04.parquet` you will need to figure out how to point to there from here

# %%
import pandas as pd

# %%
# read the file

# %%
# inspect few records
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-04-01 00:02:40   2024-04-01 00:30:42              0.0
# 1         2  2024-04-01 00:41:12   2024-04-01 00:55:29              1.0
# 2         2  2024-04-01 00:48:42   2024-04-01 01:05:30              1.0
# 3         2  2024-04-01 00:56:02   2024-04-01 01:05:09              1.0
# 4         1  2024-04-01 00:08:32   2024-04-01 00:10:24              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           5.20         1.0                  N           161             7
# 1           5.60         1.0                  N           264           264
# 2           3.55         1.0                  N           186           236
# 3           1.06         1.0                  N           137           164
# 4           0.70         1.0                  N           236           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         29.6    3.5      0.5        8.65           0.0
# 1             1         25.4    1.0      0.5       10.00           0.0
# 2             1         20.5    1.0      0.5        5.10           0.0
# 3             2         10.0    1.0      0.5        0.00           0.0
# 4             1          5.1    3.5      0.5        2.00           0.0
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee
# 0                    1.0         43.25                   2.5          0.0
# 1                    1.0         37.90                   0.0          0.0
# 2                    1.0         30.60                   2.5          0.0
# 3                    1.0         15.00                   2.5          0.0
# 4                    1.0         12.10                   2.5          0.0

# %%
# inspect size
# Out:
# (3514289, 19)

# %%
# inspect the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3514289 entries, 0 to 3514288
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# memory usage: 469.2+ MB

# %%
# calculate Trip Duration in Minutes. Call it Trip_Duration. Check out how the results look like in below cells.

# %%
# Calculate Total Trip Charge to inclide: fare amount, extra, mta_tax, tolls amount, improvement surcharge, congestion surcharge, airport fee, and tip amount
# CAll it Total_Trip_Charge

# %%
# What is the most common passenger count?
# Out:
# passenger_count
# 1.0    2399938
# 2.0     445306
# 3.0     104075
# 4.0      64286
# 0.0      39591
# 5.0      31597
# 6.0      20898
# 8.0         12
# 7.0          6
# 9.0          4
# Name: count, dtype: int64

# %%
# Add Trip Date, Trip Month Name, Trip Day Name, and Trip Year
# call them Trip_Date, Trip_Month, Trip_Day, and Trip_Month

# %%
# this is how the data looks like now
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-04-01 00:02:40   2024-04-01 00:30:42              0.0
# 1         2  2024-04-01 00:41:12   2024-04-01 00:55:29              1.0
# 2         2  2024-04-01 00:48:42   2024-04-01 01:05:30              1.0
# 3         2  2024-04-01 00:56:02   2024-04-01 01:05:09              1.0
# 4         1  2024-04-01 00:08:32   2024-04-01 00:10:24              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           5.20         1.0                  N           161             7
# 1           5.60         1.0                  N           264           264
# 2           3.55         1.0                  N           186           236
# 3           1.06         1.0                  N           137           164
# 4           0.70         1.0                  N           236           263
#
#    payment_type  ...  improvement_surcharge  total_amount  \
# 0             1  ...                    1.0         43.25
# 1             1  ...                    1.0         37.90
# 2             1  ...                    1.0         30.60
# 3             2  ...                    1.0         15.00
# 4             1  ...                    1.0         12.10
#
#    congestion_surcharge  Airport_fee  Trip_Duration  Total_Trip_Charge  \
# 0                   2.5          0.0           28.0              45.75
# 1                   0.0          0.0           14.0              37.90
# 2                   2.5          0.0           16.0              30.60
# 3                   2.5          0.0            9.0              15.00
# 4                   2.5          0.0            1.0              14.60
#
#    Trip_Date  Trip_Month  Trip_Day  Trip_Year
# 0 2024-04-01       April    Monday       2024
# 1 2024-04-01       April    Monday       2024
# 2 2024-04-01       April    Monday       2024
# 3 2024-04-01       April    Monday       2024
# 4 2024-04-01       April    Monday       2024
#
# [5 rows x 25 columns]

# %%
# inspect memory used
# Out:
# Index                         128
# VendorID                 14057156
# tpep_pickup_datetime     28114312
# tpep_dropoff_datetime    28114312
# passenger_count          28114312
# trip_distance            28114312
# RatecodeID               28114312
# store_and_fwd_flag       28114312
# PULocationID             14057156
# DOLocationID             14057156
# payment_type             28114312
# fare_amount              28114312
# extra                    28114312
# mta_tax                  28114312
# tip_amount               28114312
# tolls_amount             28114312
# improvement_surcharge    28114312
# total_amount             28114312
# congestion_surcharge     28114312
# Airport_fee              28114312
# Trip_Duration            28114312
# Total_Trip_Charge        28114312
# Trip_Date                28114312
# Trip_Month               28114312
# Trip_Day                 28114312
# Trip_Year                14057156
# dtype: int64

# %%
# inspect DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3514289 entries, 0 to 3514288
# Data columns (total 25 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
#  19  Trip_Duration          float64
#  20  Total_Trip_Charge      float64
#  21  Trip_Date              datetime64[ns]
#  22  Trip_Month             object
#  23  Trip_Day               object
#  24  Trip_Year              int32
# dtypes: datetime64[ns](1), datetime64[us](2), float64(14), int32(4), int64(1), object(3)
# memory usage: 616.7+ MB

# %%
# list existing columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee', 'Trip_Duration',
#        'Total_Trip_Charge', 'Trip_Date', 'Trip_Month', 'Trip_Day',
#        'Trip_Year'],
#       dtype='object')

# %%
# keep only specific columns 
# 'VendorID', 'passenger_count', 'trip_distance', 'store_and_fwd_flag', 'payment_type', 'Trip_Duration', 'Total_Trip_Charge', 'Trip_Date', 'Trip_Month', 'Trip_Year', 'Trip_Day'

# Reorder the columns, starting with Vendor ID, followed by all the different date/time columns example Date, Year, Month, and Day, then followed by the remaining columns

# %%
# inspect the latest DataFrame
# Out:
#    VendorID  Trip_Date  Trip_Year Trip_Month Trip_Day  passenger_count  \
# 0         1 2024-04-01       2024      April   Monday              0.0
# 1         2 2024-04-01       2024      April   Monday              1.0
# 2         2 2024-04-01       2024      April   Monday              1.0
# 3         2 2024-04-01       2024      April   Monday              1.0
# 4         1 2024-04-01       2024      April   Monday              1.0
#
#    trip_distance store_and_fwd_flag  payment_type  Trip_Duration  \
# 0           5.20                  N             1           28.0
# 1           5.60                  N             1           14.0
# 2           3.55                  N             1           16.0
# 3           1.06                  N             2            9.0
# 4           0.70                  N             1            1.0
#
#    Total_Trip_Charge
# 0              45.75
# 1              37.90
# 2              30.60
# 3              15.00
# 4              14.60

# %%
# Rename the columns - see the output below
# Out:
# /var/folders/48/j6k669vx63qd_68k2_502cl40000gn/T/ipykernel_88853/2716929451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
#    Vendor_ID  Trip_Date  Trip_Year Trip_Month Trip_Day  No_of_Passengers  \
# 0          1 2024-04-01       2024      April   Monday               0.0
# 1          2 2024-04-01       2024      April   Monday               1.0
# 2          2 2024-04-01       2024      April   Monday               1.0
# 3          2 2024-04-01       2024      April   Monday               1.0
# 4          1 2024-04-01       2024      April   Monday               1.0
#
#    trip_distance SF_Flag  Payment_Type  Trip_Duration  Total_Trip_Charge
# 0           5.20       N             1           28.0              45.75
# 1           5.60       N             1           14.0              37.90
# 2           3.55       N             1           16.0              30.60
# 3           1.06       N             2            9.0              15.00
# 4           0.70       N             1            1.0              14.60

# %%
# Save as Parquet parition by Year, Month. You can call it 'Yellow Taxi Transformed'

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# * Inspect the Parquet folder, look at the partitions. Is there someting strange? Yes/No
# * If Yes. Find which rows are causing this and capture them
# * What do you think happened?

# %% [markdown]
# **Challenge 2**
# * Go back to https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page and download the remaining months for 2024
# * Combine all the data into one. They need to have the same format/transformations as April 2024. How can you do this effeciently?
# * Export as Parquet partitioned by Year and Month
